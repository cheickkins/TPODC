# %% [markdown]
# ## Création de données
# ### DataFrame (Table)

# %%
import pandas as pd
pd.DataFrame({'Oui': [50, 21], 'Non': [131, 2]})
# Out:
#    Oui  Non
# 0   50  131
# 1   21    2

# %% [markdown]
# ### Dans cet exemple, l'entrée "0, Non" a la valeur 131. L'entrée "0, Oui" a la valeur 50, et ainsi de suite.

# %% [markdown]
# ## Meme exemple avec des chainnes de caractere

# %%
pd.DataFrame({'Bob': ['Grand', 'Noir'], 'Sue': ['Petit', 'Blanc.']})
# Out:
#      Bob     Sue
# 0  Grand   Petit
# 1   Noir  Blanc.

# %% [markdown]
# ## La liste des étiquettes de lignes (Index)

# %%
pd.DataFrame({'Bob': ['Grand', 'Noir'], 
              'Sue': ['Petit', 'Blanc.']},
             index=['Caracteristique A', 'Caracteristique B'])
# Out:
#                      Bob     Sue
# Caracteristique A  Grand   Petit
# Caracteristique B   Noir  Blanc.

# %% [markdown]
# ## Creer Une série (une séquence de valeurs de données)ou liste

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ### une série n'a pas de nom de colonne, elle n'a qu'un seul nom global

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Liste de vente')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Liste de vente, dtype: int64

# %% [markdown]
# ## Open csv Files

# %%
wine_reviews = pd.read_csv("covid (1).csv")

# %% [markdown]
# ### verifier la taille du dataframe

# %%
wine_reviews.shape
# Out:
# (209, 15)

# %%
df = pd.DataFrame(columns = ['A', 'B'], index = ['a', 'b'])
df
# Out:
#      A    B
# a  NaN  NaN
# b  NaN  NaN

# %% [markdown]
# ### Afficher par defaut les cinq premières lignes du dataframe

# %%
wine_reviews.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %% [markdown]
# ### spécifier un index_col.

# %%
wine_reviews = pd.read_csv("covid (1).csv", index_col=0)
wine_reviews.head()
# Out:
#                     Continent    Population  TotalCases  NewCases  \
# Country/Region
# USA             North America  3.311981e+08     5032179       NaN
# Brazil          South America  2.127107e+08     2917562       NaN
# India                    Asia  1.381345e+09     2025409       NaN
# Russia                 Europe  1.459409e+08      871894       NaN
# South Africa           Africa  5.938157e+07      538184       NaN
#
#                 TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# Country/Region
# USA                162804.0        NaN       2576668.0           NaN
# Brazil              98644.0        NaN       2047660.0           NaN
# India               41638.0        NaN       1377384.0           NaN
# Russia              14606.0        NaN        676357.0           NaN
# South Africa         9604.0        NaN        387316.0           NaN
#
#                 ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# Country/Region
# ...

# %%
#import pandas as pd
#reviews = pd.read_csv("covid (1).csv", index_col=0)
#pd.option.('dislay.max_rows', 5)

# %%
wine_reviews
# Out:
#                            Continent    Population  TotalCases  NewCases  \
# Country/Region
# USA                    North America  3.311981e+08     5032179       NaN
# Brazil                 South America  2.127107e+08     2917562       NaN
# India                           Asia  1.381345e+09     2025409       NaN
# Russia                        Europe  1.459409e+08      871894       NaN
# South Africa                  Africa  5.938157e+07      538184       NaN
# ...                              ...           ...         ...       ...
# Montserrat             North America  4.992000e+03          13       NaN
# Caribbean Netherlands  North America  2.624700e+04          13       NaN
# Falkland Islands       South America  3.489000e+03          13       NaN
# Vatican City                  Europe  8.010000e+02          12       NaN
# Western Sahara                Africa  5.986820e+05          10       NaN
#
# ...

# %% [markdown]
# ## pour accéder à la propriété d'un continent  nous pouvons utiliser

# %%
reviews.Continent
# Out:
# Country/Region
# USA                      North America
# Brazil                   South America
# India                             Asia
# Russia                          Europe
# South Africa                    Africa
#                              ...
# Montserrat               North America
# Caribbean Netherlands    North America
# Falkland Islands         South America
# Vatican City                    Europe
# Western Sahara                  Africa
# Name: Continent, Length: 209, dtype: object

# %% [markdown]
# ### Meme chose avec l'opérateur d'indexation ([]).

# %%
wine_reviews['Continent']
# Out:
# Country/Region
# USA                      North America
# Brazil                   South America
# India                             Asia
# Russia                          Europe
# South Africa                    Africa
#                              ...
# Montserrat               North America
# Caribbean Netherlands    North America
# Falkland Islands         South America
# Vatican City                    Europe
# Western Sahara                  Africa
# Name: Continent, Length: 209, dtype: object

# %% [markdown]
# ### Afficher une seule valeur spécifique avec l'opérateur d'indexation [] une fois de plus :

# %%
reviews['Continent'][7]
# Out:
# 'South America'

# %% [markdown]
# ### Pour sélectionner la première ligne de données dans un DataFrame

# %%
reviews.iloc[0]
# Out:
# Continent           North America
# Population            331198130.0
# TotalCases                5032179
# NewCases                      NaN
# TotalDeaths              162804.0
# NewDeaths                     NaN
# TotalRecovered          2576668.0
# NewRecovered                  NaN
# ActiveCases             2292707.0
# Serious,Critical          18296.0
# Tot Cases/1M pop          15194.0
# Deaths/1M pop               492.0
# TotalTests             63139605.0
# Tests/1M pop             190640.0
# WHO Region               Americas
# Name: USA, dtype: object

# %% [markdown]
# ### Pour obtenir une colonne avec iloc, nous pouvons procéder comme suit

# %%
reviews.iloc[:3, 0]
# Out:
# Country/Region
# USA       North America
# Brazil    South America
# India              Asia
# Name: Continent, dtype: object

# %% [markdown]
# ### pour sélectionner la colonne de Continent uniquement dans la première, la deuxième et la troisième ligne

# %%
reviews.iloc[:3, 1]
# Out:
# Country/Region
# USA       3.311981e+08
# Brazil    2.127107e+08
# India     1.381345e+09
# Name: Population, dtype: float64

# %% [markdown]
# ### sélectionner uniquement les deuxième et troisième entrées

# %%
reviews.iloc[1:3, 0]
# Out:
# Country/Region
# Brazil    South America
# India              Asia
# Name: Continent, dtype: object

# %% [markdown]
# ### Une liste

# %%
reviews.iloc[[0, 1, 2], 0]
# Out:
# Country/Region
# USA       North America
# Brazil    South America
# India              Asia
# Name: Continent, dtype: object

# %% [markdown]
# ### voici les cinq derniers éléments du jeu de données

# %%
reviews.iloc[-5:]
# Out:
#                            Continent  Population  TotalCases  NewCases  \
# Country/Region
# Montserrat             North America      4992.0          13       NaN
# Caribbean Netherlands  North America     26247.0          13       NaN
# Falkland Islands       South America      3489.0          13       NaN
# Vatican City                  Europe       801.0          12       NaN
# Western Sahara                Africa    598682.0          10       NaN
#
#                        TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# Country/Region
# Montserrat                     1.0        NaN            10.0           NaN
# Caribbean Netherlands          NaN        NaN             7.0           NaN
# Falkland Islands               NaN        NaN            13.0           NaN
# Vatican City                   NaN        NaN            12.0           NaN
# Western Sahara                 1.0        NaN             8.0           NaN
#
# ...

# %% [markdown]
# ### la première entrée

# %%
##reviews.loc[0, ['Continent']]

# %% [markdown]
# ### indexer par position. loc

# %%
reviews.loc[:, ['Continent', 'Population', 'TotalCases']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [33], line 1
# ----> 1 reviews.loc[['Continent', 'Population', 'TotalCases']]
#
# NameError: name 'reviews' is not defined

# %% [markdown]
# ### Manipulation de l'indice

# %%
reviews.set_index("Population")
# Out:
#                   Continent  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# Population
# 3.311981e+08  North America     5032179       NaN     162804.0        NaN
# 2.127107e+08  South America     2917562       NaN      98644.0        NaN
# 1.381345e+09           Asia     2025409       NaN      41638.0        NaN
# 1.459409e+08         Europe      871894       NaN      14606.0        NaN
# 5.938157e+07         Africa      538184       NaN       9604.0        NaN
# ...                     ...         ...       ...          ...        ...
# 4.992000e+03  North America          13       NaN          1.0        NaN
# 2.624700e+04  North America          13       NaN          NaN        NaN
# 3.489000e+03  South America          13       NaN          NaN        NaN
# 8.010000e+02         Europe          12       NaN          NaN        NaN
# 5.986820e+05         Africa          10       NaN          1.0        NaN
#
# ...

# %% [markdown]
# ### vérifier si chaque Pays est Asiatique ou non

# %%
reviews.Continent == 'Asia'
# Out:
# Country/Region
# USA                      False
# Brazil                   False
# India                     True
# Russia                   False
# South Africa             False
#                          ...
# Montserrat               False
# Caribbean Netherlands    False
# Falkland Islands         False
# Vatican City             False
# Western Sahara           False
# Name: Continent, Length: 209, dtype: bool

# %% [markdown]
# #### Cette opération a produit une série de booléens Vrai/Faux basés sur le Continent de chaque enregistrement.

# %% [markdown]
# ### Celle ci retourne ceux qui sont uniquement de l'Asie

# %%
reviews.loc[reviews.Continent == 'Asia']
# Out:
#                Continent    Population  TotalCases  NewCases  TotalDeaths  \
# Country/Region
# India               Asia  1.381345e+09     2025409       NaN      41638.0
# Iran                Asia  8.409762e+07      320117       NaN      17976.0
# Saudi Arabia        Asia  3.486592e+07      284226       NaN       3055.0
# Pakistan            Asia  2.212959e+08      281863       NaN       6035.0
# Bangladesh          Asia  1.648514e+08      249651       NaN       3306.0
# Turkey              Asia  8.442833e+07      237265       NaN       5798.0
# Iraq                Asia  4.030602e+07      140603       NaN       5161.0
# Philippines         Asia  1.097227e+08      119460       NaN       2150.0
# Indonesia           Asia  2.738084e+08      118753       NaN       5521.0
# Qatar               Asia  2.807805e+06      112092       NaN        178.0
# Kazakhstan          Asia  1.879867e+07       95942       NaN       1058.0
# ...

# %% [markdown]
# ### Meme chose avec un totalCases >= 61845

# %%
reviews.loc[(reviews.Continent == 'Asia') & (reviews.TotalCases >= 61845)]
# Out:
#                Continent    Population  TotalCases  NewCases  TotalDeaths  \
# Country/Region
# India               Asia  1.381345e+09     2025409       NaN      41638.0
# Iran                Asia  8.409762e+07      320117       NaN      17976.0
# Saudi Arabia        Asia  3.486592e+07      284226       NaN       3055.0
# Pakistan            Asia  2.212959e+08      281863       NaN       6035.0
# Bangladesh          Asia  1.648514e+08      249651       NaN       3306.0
# Turkey              Asia  8.442833e+07      237265       NaN       5798.0
# Iraq                Asia  4.030602e+07      140603       NaN       5161.0
# Philippines         Asia  1.097227e+08      119460       NaN       2150.0
# Indonesia           Asia  2.738084e+08      118753       NaN       5521.0
# Qatar               Asia  2.807805e+06      112092       NaN        178.0
# Kazakhstan          Asia  1.879867e+07       95942       NaN       1058.0
# ...

# %% [markdown]
# ### En ajoutant un ou logique

# %%
reviews.loc[(reviews.Continent == 'Asie') | (reviews.TotalDeaths >= 41638.0)]
# Out:
#                     Continent    Population  TotalCases  NewCases  \
# Country/Region
# USA             North America  3.311981e+08     5032179       NaN
# Brazil          South America  2.127107e+08     2917562       NaN
# India                    Asia  1.381345e+09     2025409       NaN
# Mexico          North America  1.290662e+08      462690    6590.0
# UK                     Europe  6.792203e+07      308134       NaN
#
#                 TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# Country/Region
# USA                162804.0        NaN       2576668.0           NaN
# Brazil              98644.0        NaN       2047660.0           NaN
# India               41638.0        NaN       1377384.0           NaN
# Mexico              50517.0      819.0        308848.0        4140.0
# UK                  46413.0        NaN             NaN           NaN
#
#                 ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# Country/Region
# ...

# %% [markdown]
# ### isin permet de sélectionner des données dont la valeur "est dans" une liste de valeurs.

# %%
reviews.loc[reviews.Continent.isin(['Asia', 'Europe'])]
# Out:
#                Continent    Population  TotalCases  NewCases  TotalDeaths  \
# Country/Region
# India               Asia  1.381345e+09     2025409       NaN      41638.0
# Russia            Europe  1.459409e+08      871894       NaN      14606.0
# Spain             Europe  4.675665e+07      354530       NaN      28500.0
# Iran                Asia  8.409762e+07      320117       NaN      17976.0
# UK                Europe  6.792203e+07      308134       NaN      46413.0
# ...                  ...           ...         ...       ...          ...
# Liechtenstein     Europe  3.813900e+04          89       NaN          1.0
# Macao               Asia  6.501930e+05          46       NaN          NaN
# Timor-Leste         Asia  1.320812e+06          25       NaN          NaN
# Laos                Asia  7.285750e+06          20       NaN          NaN
# Vatican City      Europe  8.010000e+02          12       NaN          NaN
#
# ...

# %% [markdown]
# ### mettre en évidence des valeurs qui sont (ou non) vides (NaN).

# %%
reviews.loc[reviews.TotalRecovered.notnull()]
# Out:
#                            Continent    Population  TotalCases  NewCases  \
# Country/Region
# USA                    North America  3.311981e+08     5032179       NaN
# Brazil                 South America  2.127107e+08     2917562       NaN
# India                           Asia  1.381345e+09     2025409       NaN
# Russia                        Europe  1.459409e+08      871894       NaN
# South Africa                  Africa  5.938157e+07      538184       NaN
# ...                              ...           ...         ...       ...
# Montserrat             North America  4.992000e+03          13       NaN
# Caribbean Netherlands  North America  2.624700e+04          13       NaN
# Falkland Islands       South America  3.489000e+03          13       NaN
# Vatican City                  Europe  8.010000e+02          12       NaN
# Western Sahara                Africa  5.986820e+05          10       NaN
#
# ...

# %% [markdown]
# ### Add critic full everyone

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# Country/Region
# USA                      everyone
# Brazil                   everyone
# India                    everyone
# Russia                   everyone
# South Africa             everyone
#                            ...
# Montserrat               everyone
# Caribbean Netherlands    everyone
# Falkland Islands         everyone
# Vatican City             everyone
# Western Sahara           everyone
# Name: critic, Length: 209, dtype: object

# %%
reviews
# Out:
#                            Continent    Population  TotalCases  NewCases  \
# Country/Region
# USA                    North America  3.311981e+08     5032179       NaN
# Brazil                 South America  2.127107e+08     2917562       NaN
# India                           Asia  1.381345e+09     2025409       NaN
# Russia                        Europe  1.459409e+08      871894       NaN
# South Africa                  Africa  5.938157e+07      538184       NaN
# ...                              ...           ...         ...       ...
# Montserrat             North America  4.992000e+03          13       NaN
# Caribbean Netherlands  North America  2.624700e+04          13       NaN
# Falkland Islands       South America  3.489000e+03          13       NaN
# Vatican City                  Europe  8.010000e+02          12       NaN
# Western Sahara                Africa  5.986820e+05          10       NaN
#
# ...

# %% [markdown]
# ### Ajouter index_bacward

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# Country/Region
# USA                      209
# Brazil                   208
# India                    207
# Russia                   206
# South Africa             205
#                         ...
# Montserrat                 5
# Caribbean Netherlands      4
# Falkland Islands           3
# Vatican City               2
# Western Sahara             1
# Name: index_backwards, Length: 209, dtype: int64

# %%
reviews
# Out:
#                            Continent    Population  TotalCases  NewCases  \
# Country/Region
# USA                    North America  3.311981e+08     5032179       NaN
# Brazil                 South America  2.127107e+08     2917562       NaN
# India                           Asia  1.381345e+09     2025409       NaN
# Russia                        Europe  1.459409e+08      871894       NaN
# South Africa                  Africa  5.938157e+07      538184       NaN
# ...                              ...           ...         ...       ...
# Montserrat             North America  4.992000e+03          13       NaN
# Caribbean Netherlands  North America  2.624700e+04          13       NaN
# Falkland Islands       South America  3.489000e+03          13       NaN
# Vatican City                  Europe  8.010000e+02          12       NaN
# Western Sahara                Africa  5.986820e+05          10       NaN
#
# ...

# %%
#import pandas as pd
#pd.set_option('max_rows', 5)
#import numpy as np
#reviews = pd.read_csv("covid (1).csv", index_col=0)

# %%
## Restrucutre de données

# %%
reviews.TotalCases.describe()
# Out:
# count    2.090000e+02
# mean     9.171850e+04
# std      4.325867e+05
# min      1.000000e+01
# 25%      7.120000e+02
# 50%      4.491000e+03
# 75%      3.689600e+04
# max      5.032179e+06
# Name: TotalCases, dtype: float64

# %%
reviews.Continent.describe()
# Out:
# count        208
# unique         6
# top       Africa
# freq          57
# Name: Continent, dtype: object

# %% [markdown]
# ### statistiques récapitulatives simples

# %%
reviews.TotalTests.mean()
# Out:
# 1402404.7015706806

# %% [markdown]
# ### pour voir une liste de valeurs uniques

# %%
reviews.Continent.unique()
# Out:
# array(['North America', 'South America', 'Asia', 'Europe', 'Africa',
#        'Australia/Oceania', nan], dtype=object)

# %% [markdown]
# ### une liste de valeurs uniques et leur fréquence d'apparition

# %%
reviews.Continent.value_counts()
# Out:
# Africa               57
# Asia                 48
# Europe               48
# North America        35
# South America        14
# Australia/Oceania     6
# Name: Continent, dtype: int64

# %% [markdown]
# ###

# %%
review_TotalCases = reviews.TotalCases.mean()
reviews.TotalCases.map(lambda p: p - review_TotalCases)
# Out:
# Country/Region
# USA                      4.940461e+06
# Brazil                   2.825844e+06
# India                    1.933691e+06
# Russia                   7.801755e+05
# South Africa             4.464655e+05
#                              ...
# Montserrat              -9.170550e+04
# Caribbean Netherlands   -9.170550e+04
# Falkland Islands        -9.170550e+04
# Vatican City            -9.170650e+04
# Western Sahara          -9.170850e+04
# Name: TotalCases, Length: 209, dtype: float64

# %% [markdown]
# ### Changer la valeur sans affecter celle d'origine

# %%
def remean_TotalCases(row):
    row.TotalCases = row.TotalCases - review_TotalCases
    return row

reviews.apply(remean_TotalCases, axis='columns')
# Out:
#                            Continent    Population    TotalCases  NewCases  \
# Country/Region
# USA                    North America  3.311981e+08  4.940461e+06       NaN
# Brazil                 South America  2.127107e+08  2.825844e+06       NaN
# India                           Asia  1.381345e+09  1.933691e+06       NaN
# Russia                        Europe  1.459409e+08  7.801755e+05       NaN
# South Africa                  Africa  5.938157e+07  4.464655e+05       NaN
# ...                              ...           ...           ...       ...
# Montserrat             North America  4.992000e+03 -9.170550e+04       NaN
# Caribbean Netherlands  North America  2.624700e+04 -9.170550e+04       NaN
# Falkland Islands       South America  3.489000e+03 -9.170550e+04       NaN
# Vatican City                  Europe  8.010000e+02 -9.170650e+04       NaN
# Western Sahara                Africa  5.986820e+05 -9.170850e+04       NaN
#
# ...

# %%
reviews
# Out:
#                            Continent    Population  TotalCases  NewCases  \
# Country/Region
# USA                    North America  3.311981e+08     5032179       NaN
# Brazil                 South America  2.127107e+08     2917562       NaN
# India                           Asia  1.381345e+09     2025409       NaN
# Russia                        Europe  1.459409e+08      871894       NaN
# South Africa                  Africa  5.938157e+07      538184       NaN
# ...                              ...           ...         ...       ...
# Montserrat             North America  4.992000e+03          13       NaN
# Caribbean Netherlands  North America  2.624700e+04          13       NaN
# Falkland Islands       South America  3.489000e+03          13       NaN
# Vatican City                  Europe  8.010000e+02          12       NaN
# Western Sahara                Africa  5.986820e+05          10       NaN
#
# ...

# %%
reviews.head(1)
# Out:
#                     Continent   Population  TotalCases  NewCases  TotalDeaths  \
# Country/Region
# USA             North America  331198130.0     5032179       NaN     162804.0
#
#                 NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# Country/Region
# USA                   NaN       2576668.0           NaN    2292707.0
#
#                 Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# Country/Region
# USA                      18296.0           15194.0          492.0  63139605.0
#
#                 Tests/1M pop WHO Region    critic  index_backwards
# Country/Region
# USA                 190640.0   Americas  everyone              209

# %% [markdown]
# ### Changer la valeur sans affecter celle d'origine

# %%
review_TotalCases_mean = reviews.TotalCases.mean()
reviews.TotalCases - review_TotalCases_mean
# Out:
# Country/Region
# USA                      4.940461e+06
# Brazil                   2.825844e+06
# India                    1.933691e+06
# Russia                   7.801755e+05
# South Africa             4.464655e+05
#                              ...
# Montserrat              -9.170550e+04
# Caribbean Netherlands   -9.170550e+04
# Falkland Islands        -9.170550e+04
# Vatican City            -9.170650e+04
# Western Sahara          -9.170850e+04
# Name: TotalCases, Length: 209, dtype: float64

# %%
reviews
# Out:
#                            Continent    Population  TotalCases  NewCases  \
# Country/Region
# USA                    North America  3.311981e+08     5032179       NaN
# Brazil                 South America  2.127107e+08     2917562       NaN
# India                           Asia  1.381345e+09     2025409       NaN
# Russia                        Europe  1.459409e+08      871894       NaN
# South Africa                  Africa  5.938157e+07      538184       NaN
# ...                              ...           ...         ...       ...
# Montserrat             North America  4.992000e+03          13       NaN
# Caribbean Netherlands  North America  2.624700e+04          13       NaN
# Falkland Islands       South America  3.489000e+03          13       NaN
# Vatican City                  Europe  8.010000e+02          12       NaN
# Western Sahara                Africa  5.986820e+05          10       NaN
#
# ...

# %% [markdown]
# ### un moyen simple de combiner les informations

# %%
#reviews.Continent + " - " + reviews.TotalDeaths

# %% [markdown]
# ### Page 4 Group by (REGROUPER PAR)

# %%
reviews.groupby('Continent').Continent.count()
# Out:
# Continent
# Africa               57
# Asia                 48
# Australia/Oceania     6
# Europe               48
# North America        35
# South America        14
# Name: Continent, dtype: int64

# %%
### Afficher le minimum de chaque categories

# %%
reviews.groupby('Continent').TotalDeaths.min()
# Out:
# Continent
# Africa                1.0
# Asia                  3.0
# Australia/Oceania     1.0
# Europe                1.0
# North America         1.0
# South America        22.0
# Name: TotalDeaths, dtype: float64

# %%
reviews.groupby([ 'Continent']).apply(lambda df: df.loc[df.TotalDeaths.idxmax()])
# Out:
#                            Continent    Population  TotalCases  NewCases  \
# Continent
# Africa                        Africa  5.938157e+07      538184       NaN
# Asia                            Asia  1.381345e+09     2025409       NaN
# Australia/Oceania  Australia/Oceania  2.552886e+07       19890       NaN
# Europe                        Europe  6.792203e+07      308134       NaN
# North America          North America  3.311981e+08     5032179       NaN
# South America          South America  2.127107e+08     2917562       NaN
#
#                    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# Continent
# Africa                  9604.0        NaN        387316.0           NaN
# Asia                   41638.0        NaN       1377384.0           NaN
# Australia/Oceania        255.0        NaN         10941.0           NaN
# Europe                 46413.0        NaN             NaN           NaN
# ...

# %%
reviews.groupby(['Continent']).Population.agg([len, min, max])
# Out:
#                    len       min           max
# Continent
# Africa              57   98408.0  2.066063e+08
# Asia                48  437893.0  1.381345e+09
# Australia/Oceania    6  281072.0  2.552886e+07
# Europe              48     801.0  1.459409e+08
# North America       35    4992.0  3.311981e+08
# South America       14    3489.0  2.127107e+08
